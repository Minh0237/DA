# %% [markdown]
# <a href="https://colab.research.google.com/github/Minh0237/DA/blob/main/08_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Iris

# %% [markdown]
# ### Introduction:
#
# This exercise may seem a little bit strange, but keep doing it.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data).

# %% [markdown]
# ### Step 3. Assign it to a variable called iris

# %%
iris = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data', sep = ',')

# %% [markdown]
# ### Step 4. Create columns for the dataset

# %%
# 1. sepal_length (in cm)
# 2. sepal_width (in cm)
# 3. petal_length (in cm)
# 4. petal_width (in cm)
# 5. class

iris.columns = ['sepal_length (in cm)', 'sepal_width (in cm)', 'petal_length (in cm)', 'petal_width (in cm)', 'class']
iris
# Out:
#      sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 0                     4.9                  3.0                   1.4
# 1                     4.7                  3.2                   1.3
# 2                     4.6                  3.1                   1.5
# 3                     5.0                  3.6                   1.4
# 4                     5.4                  3.9                   1.7
# ..                    ...                  ...                   ...
# 144                   6.7                  3.0                   5.2
# 145                   6.3                  2.5                   5.0
# 146                   6.5                  3.0                   5.2
# 147                   6.2                  3.4                   5.4
# 148                   5.9                  3.0                   5.1
#
#      petal_width (in cm)           class
# 0                    0.2     Iris-setosa
# 1                    0.2     Iris-setosa
# ...

# %% [markdown]
# ### Step 5.  Is there any missing value in the dataframe?

# %%
iris.isna().sum()
# Out:
# sepal_length (in cm)    0
# sepal_width (in cm)     0
# petal_length (in cm)    0
# petal_width (in cm)     0
# class                   0
# dtype: int64

# %% [markdown]
# ### Step 6.  Lets set the values of the rows 10 to 29 of the column 'petal_length' to NaN

# %%
iris.replace(iris['petal_length (in cm)'][10:30], np.nan, inplace = True)
iris.iloc[10:30]
# Out:
#     sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 10                   4.8                  3.4                   1.6
# 11                   4.8                  3.0                   1.4
# 12                   4.3                  3.0                   1.1
# 13                   5.8                  4.0                   1.2
# 14                   5.7                  4.4                   1.5
# 15                   5.4                  3.9                   1.3
# 16                   5.1                  3.5                   1.4
# 17                   5.7                  3.8                   1.7
# 18                   5.1                  3.8                   1.5
# 19                   5.4                  3.4                   1.7
# 20                   5.1                  3.7                   1.5
# 21                   4.6                  3.6                   1.0
# 22                   5.1                  3.3                   1.7
# ...

# %% [markdown]
# ### Step 7. Good, now lets substitute the NaN values to 1.0

# %%
iris['petal_length (in cm)'].fillna(1, inplace = True)

# %% [markdown]
# ### Step 8. Now let's delete the column class

# %%
iris.drop('class', axis = 1, inplace = True)
iris
# Out:
#      sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 0                     4.9                  3.0                   1.4
# 1                     4.7                  3.2                   1.3
# 2                     4.6                  3.1                   1.5
# 3                     5.0                  3.6                   1.4
# 4                     5.4                  3.9                   1.7
# ..                    ...                  ...                   ...
# 144                   6.7                  3.0                   5.2
# 145                   6.3                  2.5                   5.0
# 146                   6.5                  3.0                   5.2
# 147                   6.2                  3.4                   5.4
# 148                   5.9                  3.0                   5.1
#
#      petal_width (in cm)
# 0                    0.2
# 1                    0.2
# 2                    0.2
# 3                    0.2
# ...

# %% [markdown]
# ### Step 9.  Set the first 3 rows as NaN

# %%
iris.iloc[0:2] = np.nan

# %% [markdown]
# ### Step 10.  Delete the rows that have NaN

# %%
iris.dropna(inplace = True)

# %% [markdown]
# ### Step 11. Reset the index so it begins with 0 again

# %%
iris.reset_index(inplace = True)
iris
# Out:
#      level_0  index  sepal_length (in cm)  sepal_width (in cm)  \
# 0          0      2                   4.6                  3.1
# 1          1      3                   5.0                  3.6
# 2          2      4                   5.4                  3.9
# 3          3      5                   4.6                  3.4
# 4          4      6                   5.0                  3.4
# ..       ...    ...                   ...                  ...
# 142      142    144                   6.7                  3.0
# 143      143    145                   6.3                  2.5
# 144      144    146                   6.5                  3.0
# 145      145    147                   6.2                  3.4
# 146      146    148                   5.9                  3.0
#
#      petal_length (in cm)  petal_width (in cm)
# 0                     1.5                  0.2
# 1                     1.4                  0.2
# 2                     1.7                  0.4
# ...

# %% [markdown]
# ### BONUS: Create your own question and answer it.
