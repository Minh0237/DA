# %% [markdown]
# <a href="https://colab.research.google.com/github/Minh0237/DA/blob/main/04_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ex - GroupBy

# %% [markdown]
# ### Introduction:
#
# GroupBy can be summarized as Split-Apply-Combine.
#
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# Check out this [Diagram](http://i.imgur.com/yjNkiwL.png)
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://github.com/thieu1995/csv-files/blob/main/data/pandas/drinks.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called drinks.

# %%
drinks = pd.read_csv('https://raw.githubusercontent.com/thieu1995/csv-files/main/data/pandas/drinks.csv', index_col=0)
drinks
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
# ...                    ...              ...            ...
# Venezuela              333              100              3
# Vietnam                111                2              1
# Yemen                    6                0              0
# Zambia                  32               19              4
# Zimbabwe                64               18              4
#
#              total_litres_of_pure_alcohol continent
# country
# Afghanistan                           0.0        AS
# Albania                               4.9        EU
# Algeria                               0.7        AF
# ...

# %% [markdown]
# ### Step 4. Which continent drinks more beer on average?

# %%
avgbeer = drinks['beer_servings'].mean()
drinks[(drinks['beer_servings'] > avgbeer)]
# Out:
#                 beer_servings  spirit_servings  wine_servings  \
# country
# Andorra                   245              138            312
# Angola                    217               57             45
# Argentina                 193               25            221
# Australia                 261               72            212
# Austria                   279               75            191
# ...                       ...              ...            ...
# United Kingdom            219              126            195
# USA                       249              158             84
# Uruguay                   115               35            220
# Venezuela                 333              100              3
# Vietnam                   111                2              1
#
#                 total_litres_of_pure_alcohol continent
# country
# Andorra                                 12.4        EU
# Angola                                   5.9        AF
# ...

# %% [markdown]
# ### Step 5. For each continent print the statistics for wine consumption.

# %%
drinks.groupby('continent')['wine_servings'].count()
# Out:
# continent
# AF    53
# AS    44
# EU    45
# OC    16
# SA    12
# Name: wine_servings, dtype: int64

# %% [markdown]
# ### Step 6. Print the mean alcohol consumption per continent for every column

# %%
continentgr = drinks.groupby('continent', dropna = False)['total_litres_of_pure_alcohol'].mean()
continentgr
# Out:
# continent
# AF     3.007547
# AS     2.170455
# EU     8.617778
# OC     3.381250
# SA     6.308333
# NaN    5.995652
# Name: total_litres_of_pure_alcohol, dtype: float64

# %% [markdown]
# ### Step 7. Print the median alcohol consumption per continent for every column

# %%
drinks.groupby('continent', dropna = False)['total_litres_of_pure_alcohol'].median()
# Out:
# continent
# AF      2.30
# AS      1.20
# EU     10.00
# OC      1.75
# SA      6.85
# NaN     6.30
# Name: total_litres_of_pure_alcohol, dtype: float64

# %% [markdown]
# ### Step 8. Print the mean, min and max values for spirit consumption.
# #### This time output a DataFrame

# %%
pd.DataFrame(drinks['spirit_servings'].describe())
# Out:
#        spirit_servings
# count       193.000000
# mean         80.994819
# std          88.284312
# min           0.000000
# 25%           4.000000
# 50%          56.000000
# 75%         128.000000
# max         438.000000
