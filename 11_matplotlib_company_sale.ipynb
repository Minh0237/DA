# %% [markdown]
# <a href="https://colab.research.google.com/github/Minh0237/DA/blob/main/11_matplotlib_company_sale.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Visualizing Company Sale data

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter

import warnings
warnings.filterwarnings("ignore")

# set this so the graphs open internally
# %matplotlib inline

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://github.com/thieu1995/csv-files/blob/main/data/matplotlib/company_sales_data.csv).

# %%
df = pd.read_csv('https://raw.githubusercontent.com/thieu1995/csv-files/main/data/matplotlib/company_sales_data.csv')
df
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
#     moisturizer  total_units  total_profit
# 0          1500        21100        211000
# 1          1200        18330        183300
# 2          1340        22470        224700
# 3          1130        22270        222700
# 4          1740        20960        209600
# 5          1555        20140        201400
# 6          1120        29550        295500
# 7          1400        36140        361400
# 8          1780        23400        234000
# 9          1890        26670        266700
# 10         2100        41280        412800
# 11         1760        30020        300200

# %% [markdown]
# ### Exercise 1: Read Total profit of all months and show it using a line plot
#
# ![img](https://github.com/thieu1995/pandas/blob/main/11_matplotlib/company-sale/img/01.png?raw=1)

# %%
x = df['month_number'].tolist()
y = df['total_profit']

plt.plot(x, y)
plt.xticks(x)
plt.yticks([100000, 200000, 300000, 400000, 500000])
plt.xlabel('Month number')
plt.ylabel('Profit')
plt.title('Company profit each month')
plt.show()

# %% [markdown]
# ### Exercise 2: Get total profit of all months and show line plot with the following Style properties
#
# ![img](https://github.com/thieu1995/pandas/blob/main/11_matplotlib/company-sale/img/02.png?raw=1)

# %%
plt.plot(x, y, linestyle = '--', linewidth = 3, color = 'r', marker = 'o', mfc = 'k')
plt.xticks(x)
plt.xlabel('Month number')
plt.ylabel('Profit')
plt.yticks([100000, 200000, 300000, 400000, 500000])
plt.title('Company profit each month')
plt.legend(labels = ['Profit data of last year'], loc = 'lower right')
plt.show()

# %% [markdown]
# ### Exercise 3: Read all product sales data and show it  using a multiline plot
#
# ![img](https://github.com/thieu1995/pandas/blob/main/11_matplotlib/company-sale/img/03.png?raw=1)

# %%
plt.plot(x, df.facecream, c = 'tab:blue', linewidth = 3, label='Facecream Sales Data', marker = 'o')
plt.plot(x, df['facewash'], c = 'y', linewidth = 3, label='Facewash Sales Data', marker = 'o')
plt.plot(x, df['toothpaste'], c = 'tab:green', linewidth = 3, label='Toothpaste Sales Data', marker = 'o')
plt.plot(x, df['bathingsoap'], color='r', linewidth = 3, label='Bathingsoap Sales Data', marker = 'o')
plt.plot(x, df['shampoo'], c = 'tab:purple', linewidth = 3, label='Shampoo Sales Data', marker = 'o')
plt.plot(x, df['moisturizer'], c ='tab:brown', linewidth = 3, label='Moistrurizer Sales Data', marker = 'o')

plt.legend()
plt.title('Sales Data')
plt.xlabel('Month Number')
plt.ylabel('Sales units in number')
plt.yticks([1000, 2000, 4000, 6000, 8000, 10000, 12000, 15000, 18000])
plt.show()

# %% [markdown]
# ### Exercise 4: Read toothpaste sales data of each month and show it using a scatter plot
# ![img](https://github.com/thieu1995/pandas/blob/main/11_matplotlib/company-sale/img/04.png?raw=1)

# %%
plt.scatter(x, df['toothpaste'], label = 'Tooth paste Sales data')
plt.grid(linestyle='--', linewidth = 1.0, alpha=1, zorder = 1)
plt.xticks(x)
plt.xlabel('Month Number')
plt.ylabel('Number of units Sold')
plt.title('Tooth paste Sales data')
plt.legend()
plt.show()

# %% [markdown]
# ### Exercise 5: Read face cream and facewash product sales data and show it using the bar chart
#
# ![img](https://github.com/thieu1995/pandas/blob/main/11_matplotlib/company-sale/img/05.png?raw=1)

# %%
import numpy as np
r = np.arange(len(x))
plt.bar(r, df['facecream'], width=0.2, label='Face cream sales data')
plt.bar(r+0.2, df['facewash'], width=0.2, label='Face wash sales data')
plt.grid(True, linestyle='--', linewidth = 1)
plt.xlabel('Month Number')
plt.ylabel('Salse units in number')
plt.title('Facewash and Facecream sales data')
plt.legend(loc = 'upper left')
plt.show()

# %% [markdown]
# ### Exercise 6: Read sales data of bathing soap of all months and show it using a bar chart. Save this plot to your hard disk
#
# ![img](https://github.com/thieu1995/pandas/blob/main/11_matplotlib/company-sale/img/06.png?raw=1)

# %%
plt.bar(x, df['bathingsoap'], label = 'bathingsoap Sales data')
plt.grid(True, linestyle='--', linewidth = 1.0)
plt.xticks(x)
plt.xlabel('Month Number')
plt.ylabel('Sales units in number')
plt.title('bathingsoap Sales data')
plt.show()

# %% [markdown]
# ### Exercise 7: Read the total profit of each month and show it using the histogram to see the most common profit ranges
#
# ![img](https://github.com/thieu1995/pandas/blob/main/11_matplotlib/company-sale/img/07.png?raw=1)

# %%
plt.hist(df['total_profit'], [150000, 175000, 200000, 225000, 250000, 300000, 350000], label = 'Profit data')
plt.xlabel('profit range in dollar')
plt.ylabel('Actual Profit in dollar')
plt.title('Profit data')
plt.legend(loc = 'upper left')
plt.xticks([150000, 175000, 200000, 225000, 250000, 300000, 350000])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Exercise 8: Calculate total sale data for last year for each product and show it using a Pie chart
#
# ![img](https://github.com/thieu1995/pandas/blob/main/11_matplotlib/company-sale/img/08.png?raw=1)

# %%
y = [df.facecream.sum(), df.facewash.sum(), df.toothpaste.sum(), df.bathingsoap.sum(), df.shampoo.sum(), df.moisturizer.sum()]
plt.pie(y, labels = ['FaceCream', 'FaceWash', 'ToothPaste', 'Bathing soap', 'Shampoo', 'Moisturizer'], autopct = '%1.1f%%')
plt.legend(loc = 'lower right')
plt.title('Sales data')
plt.show()

# %% [markdown]
# ### Exercise 9: Read Bathing soap facewash of all months and display it using the Subplot
#
# ![img](https://github.com/thieu1995/pandas/blob/main/11_matplotlib/company-sale/img/09.png?raw=1)

# %%
plt.subplot(211)
plt.plot(x, df.bathingsoap, linewidth = 3, color = 'k', marker = 'o')
plt.xticks([])
plt.title('Sales data of Bathingsoap')
plt.yticks([7500, 10000, 12500])

plt.subplot(212)
plt.plot(x, df.facewash, linewidth = 3, color = 'r', marker = 'o')
plt.xticks(x)
plt.title('Sales data of a FaceWash')
plt.yticks([1500, 2000])

plt.xlabel('Month Number')
plt.ylabel('Sales units in number')
plt.show()

# %% [markdown]
# ### Exercise 10: Read all product sales data and show it using the stack plot
#
# ![img](https://github.com/thieu1995/pandas/blob/main/11_matplotlib/company-sale/img/10.png?raw=1)

# %%
plt.plot([], [], label = 'FaceCream', c = 'm', linewidth = 5)
plt.plot([], [], label = 'FaceWash', c = 'c', linewidth = 5)
plt.plot([], [], label = 'Tooth Paste', c = 'r', linewidth = 5)
plt.plot([], [], label = 'Bathing soap', c = 'k', linewidth = 5)
plt.plot([], [], label = 'Shampoo', c = 'g', linewidth = 5)
plt.plot([], [], label = 'Moistrurizer', c = 'y', linewidth = 5)

plt.stackplot(x, df.facecream.tolist(), df.facewash.tolist(), df.toothpaste, df.bathingsoap, df.shampoo, df.moisturizer, colors = ['m', 'c', 'r', 'k', 'g', 'y'])
plt.xlabel('Month Number')
plt.ylabel('Sales units in Number')
plt.title('All product sales data using stack plot')
plt.legend(loc = 'upper left')
plt.show()

# %% [markdown]
# ### Exercise 6: Read sales data of bathing soap of all months and show it using a bar chart. Save this plot to your hard disk
#
# ![img](https://github.com/thieu1995/pandas/blob/main/11_matplotlib/company-sale/img/06.png?raw=1)

# %% [markdown]
# ### Exercise 7: Read the total profit of each month and show it using the histogram to see the most common profit ranges
#
# ![img](https://github.com/thieu1995/pandas/blob/main/11_matplotlib/company-sale/img/07.png?raw=1)

# %% [markdown]
# ### Exercise 8: Calculate total sale data for last year for each product and show it using a Pie chart
#
# ![img](https://github.com/thieu1995/pandas/blob/main/11_matplotlib/company-sale/img/08.png?raw=1)

# %% [markdown]
# ### Exercise 9: Read Bathing soap facewash of all months and display it using the Subplot
#
# ![img](https://github.com/thieu1995/pandas/blob/main/11_matplotlib/company-sale/img/09.png?raw=1)

# %% [markdown]
# ### Exercise 10: Read all product sales data and show it using the stack plot
#
# ![img](https://github.com/thieu1995/pandas/blob/main/11_matplotlib/company-sale/img/10.png?raw=1)

# %% [markdown]
# ### Exercise 6: Read sales data of bathing soap of all months and show it using a bar chart. Save this plot to your hard disk
#
# ![img](https://github.com/thieu1995/pandas/blob/main/11_matplotlib/company-sale/img/06.png?raw=1)

# %% [markdown]
# ### Exercise 7: Read the total profit of each month and show it using the histogram to see the most common profit ranges
#
# ![img](https://github.com/thieu1995/pandas/blob/main/11_matplotlib/company-sale/img/07.png?raw=1)

# %% [markdown]
# ### Exercise 8: Calculate total sale data for last year for each product and show it using a Pie chart
#
# ![img](https://github.com/thieu1995/pandas/blob/main/11_matplotlib/company-sale/img/08.png?raw=1)

# %% [markdown]
# ### Exercise 9: Read Bathing soap facewash of all months and display it using the Subplot
#
# ![img](https://github.com/thieu1995/pandas/blob/main/11_matplotlib/company-sale/img/09.png?raw=1)

# %% [markdown]
# ### Exercise 10: Read all product sales data and show it using the stack plot
#
# ![img](https://github.com/thieu1995/pandas/blob/main/11_matplotlib/company-sale/img/10.png?raw=1)
